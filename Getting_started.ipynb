# %% [markdown]
# <a href="https://colab.research.google.com/github/AtalGupta/OpenCV/blob/main/Getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.8.0

# %%
# !wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# !unzip -qq images.zip
# Out:
# --2023-08-22 19:24:14--  https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# Resolving moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)... 52.95.148.134, 52.95.191.2, 52.95.149.38, ...
# Connecting to moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)|52.95.148.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29586716 (28M) [application/zip]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]  28.22M  21.2MB/s    in 1.3s
#
# 2023-08-22 19:24:16 (21.2 MB/s) - ‘images.zip’ saved [29586716/29586716]

# %% [markdown]
# Loading Images

# %%
image1 = cv2.imread('./images/Hillary.jpg')

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# by creating function of imshow

# %%
def imshow(title ="", image=None):
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show

# %%
imshow("displaying_image", image1)

# %%
cv2.imwrite("save.jpg", image1)
# Out:
# True

# %%
import numpy as np
print(image1.shape)
# Out:
# (273, 184, 3)

# %%
print("Height of Image: {} pixels" .format(int(image1.shape[0])))
print("widtg of Image: {} pixels" .format(int(image1.shape[1])))
print("depth of Color component of Image: {} pixels" .format(int(image1.shape[2])))
# Out:
# Height of Image: 273 pixels
# widtg of Image: 184 pixels
# depth of Color component of Image: 3 pixels
